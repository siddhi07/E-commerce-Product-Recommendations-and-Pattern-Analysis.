# %% [markdown]
# ### Files required to run this colab file:
# * Groceries_dataset.csv
# * 5000_meta_Grocery_and_Gourmet_Food.csv OR meta_Grocery_and_Gourmet_Food.csv
# * 5000_Reviews_Grocery_and_Gourmet_Food.csv OR Reviews_Grocery_and_Gourmet_Food.csv

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Amazon Product Details Dataset (Meta) -> for sentiment analysis

# %%
df_sentiment = pd.read_csv('/content/meta_Grocery_and_Gourmet_Food.csv')

# %%
df_sentiment.tail()
# Out:
#      parent_asin main_category  \
# 6239  B0C1M7K2R8       Grocery
# 6240  B08D3W96DK       Grocery
# 6241  B07JZ6BMLQ       Grocery
# 6242  B0713VD3HF       Grocery
# 6243  B0BRRT3D8Z       Grocery
#
#                                                   title  average_rating  \
# 6239  Sunny Fruit Organic Figs,Tender and Juicy Drie...             4.6
# 6240  GERBS Dried Mango Slices Unsweetened 2 LBS. | ...             3.9
# 6241  Old Wisconsin Snack Sticks, Turkey, 1.5-Ounce ...             4.5
# 6242                  Pickle Juice Soda Pop - 3 Bottles             3.4
# 6243           Prego Traditional Pasta Sauce, 67 Oz Jar             4.7
#
#       rating_number  price          store  \
# 6239            687  21.95    SUNNY FRUIT
# 6240           3974  31.99          GERBS
# 6241             83    NaN  Old Wisconsin
# 6242             34  12.99        Lesters
# 6243           2654    NaN          Prego
#
#                                                features  \
# 6239  12 Convenient & Mess free Portion pack, Great ...
# 6240  Naturally Dried Mango - No Sugar Added (unswee...
# 6241  Superior quality | All meat--no binders, fille...
# 6242                                                NaN
# 6243  One 67 oz jar of Prego Traditional Pasta Sauce...
#
#                                             description  \
# 6239  The Sunny fruit difference begins at the sourc...
# 6240                                                NaN
# 6241  Old Wisconsin Turkey Snack Sticks are great fo...
# 6242                3-pack of pickle-flavored soda pop.
# 6243  Be the hero at dinner with Prego Traditional P...
#
#                                                  images  ...  \
# 6239                                                NaN  ...
# 6240  https://m.media-amazon.com/images/I/515yOXg0ka...  ...
# 6241  https://m.media-amazon.com/images/I/81kbcxwhxt...  ...
# 6242  https://m.media-amazon.com/images/I/91CuceafAf...  ...
# 6243  https://m.media-amazon.com/images/I/81yPY1XI-t...  ...
#
#       caffeine_content roast_level  unit_count  \
# 6239               NaN         NaN         NaN
# 6240               NaN         NaN         NaN
# 6241               NaN         NaN         NaN
# 6242               NaN         NaN  3.00 Count
# 6243               NaN         NaN         NaN
#
#                        package_dimensions           upc  \
# 6239                                  NaN  842515010118
# 6240     8.6 x 6.6 x 3.3 inches; 2 Pounds  828678203765
# 6241  15.5 x 3.1 x 3.1 inches; 1.5 Ounces  073170731241
# 6242                                  NaN           NaN
# 6243                                  NaN           NaN
#
#                       manufacturer  flavor color item_weight country_of_origin
# 6239                Safe food corp     NaN   NaN         NaN               NaN
# 6240  GERBS ALLERGY FRIENDLY FOODS     NaN   NaN         NaN               NaN
# 6241                 Old Wisconsin     NaN   NaN         NaN               NaN
# 6242                           NaN  Pickle   NaN    5 Pounds               NaN
# 6243                           NaN     NaN   NaN         NaN               NaN
#
# [5 rows x 26 columns]

# %%
df_sentiment.shape
# Out:
# (6244, 26)

# %%
df_sentiment.columns
# Out:
# Index(['parent_asin', 'main_category', 'title', 'average_rating',
#        'rating_number', 'price', 'store', 'features', 'description', 'images',
#        'num_images', 'has_videos', 'bought_together', 'categories', 'brand',
#        'item_form', 'caffeine_content', 'roast_level', 'unit_count',
#        'package_dimensions', 'upc', 'manufacturer', 'flavor', 'color',
#        'item_weight', 'country_of_origin'],
#       dtype='object')

# %%
#calculate number of nans in each column
df_sentiment.isna().sum()
# Out:
# parent_asin              0
# main_category           42
# title                    0
# average_rating           0
# rating_number            0
# price                 3449
# store                  151
# features              1391
# description           2196
# images                 901
# num_images               1
# has_videos               1
# bought_together       6244
# categories             545
# brand                 3731
# item_form             4956
# caffeine_content      6085
# roast_level           6126
# unit_count            4635
# package_dimensions    2829
# upc                   2530
# manufacturer          1474
# flavor                4627
# color                 6128
# item_weight           5176
# country_of_origin     5610
# dtype: int64

# %%
# remove unnecessary columns
df_sentiment = df_sentiment.drop(['features', 'num_images', 'has_videos', 'bought_together', 'item_form', 'caffeine_content', 'roast_level', 'package_dimensions', 'upc', 'item_weight', 'country_of_origin'], axis=1)
# rename 'images' to 'image_url
df_sentiment = df_sentiment.rename(columns={'images': 'image_url'})
df_sentiment.columns
# Out:
# Index(['parent_asin', 'main_category', 'title', 'average_rating',
#        'rating_number', 'price', 'store', 'description', 'image_url',
#        'categories', 'brand', 'unit_count', 'manufacturer', 'flavor', 'color'],
#       dtype='object')

# %%
df_sentiment['categories'].head(20)
# Out:
# 0           Grocery & Gourmet Food > Beverages > Coffee
# 1     Grocery & Gourmet Food > Breads & Bakery > Coo...
# 2     Grocery & Gourmet Food > Pantry Staples > Cann...
# 3     Grocery & Gourmet Food > Snacks & Sweets > Cho...
# 4                                                   NaN
# 5     Grocery & Gourmet Food > Beverages > Bottled B...
# 6     Grocery & Gourmet Food > Pantry Staples > Soup...
# 7     Grocery & Gourmet Food > Pantry Staples > Cook...
# 8     Grocery & Gourmet Food > Home Brewing & Winema...
# 9     Grocery & Gourmet Food > Pantry Staples > Sauc...
# 10    Grocery & Gourmet Food > Beverages > Coffee > ...
# 11    Grocery & Gourmet Food > Breakfast Foods > Cer...
# 12    Grocery & Gourmet Food > Pantry Staples > Drie...
# 13    Grocery & Gourmet Food > Pantry Staples > Cook...
# 14    Grocery & Gourmet Food > Snacks & Sweets > Sna...
# 15                                                  NaN
# 16    Grocery & Gourmet Food > Snacks & Sweets > Can...
# 17    Grocery & Gourmet Food > Food & Beverage Gifts...
# 18    Grocery & Gourmet Food > Pantry Staples > Herb...
# 19    Grocery & Gourmet Food > Breads & Bakery > Coo...
# Name: categories, dtype: object

# %% [markdown]
# ### Reasons for removing:
#
# * features --> similar to description, kept description instead
# * num_images --> not needed, only need image url
# * has_videos --> not needed, only need image url
# * bought_together --> not needed as we are doing market baset analysis on the other dataset
# * item_form --> too many missing values and not neccesary
# * caffeine_content --> not needed as it is only relevant for coffee
# * roast_level --> not needed as it is only relevant for coffee
# * package_dimensions --> too many missing values
# * upc --> not needed
# * item_weight --> similar to unit_count, kept unit_count instead as it has lesser missing values
# * country_of_origin --> not needed

# %%
df_sentiment['main_category'].unique()
# Out:
# array(['Grocery', 'Amazon Home', 'Industrial & Scientific',
#        'Health & Personal Care', nan, 'Home Audio & Theater',
#        'Toys & Games', 'All Beauty', 'Pet Supplies',
#        'Tools & Home Improvement', 'Arts, Crafts & Sewing',
#        'AMAZON FASHION', 'Sports & Outdoors', 'Office Products',
#        'Cell Phones & Accessories', 'All Electronics', 'Baby',
#        'Automotive', 'Musical Instruments', 'Buy a Kindle',
#        'Digital Music'], dtype=object)

# %%
# only keep the rows where the main_category = 'Grocery'
df_sentiment = df_sentiment[df_sentiment['main_category'] == 'Grocery']
df_sentiment['main_category'].unique()
# Out:
# array(['Grocery'], dtype=object)

# %%
# don't need main_category as we only kept the 'Grocery' category
df_sentiment = df_sentiment.drop('main_category', axis=1)
df_sentiment.columns
# Out:
# Index(['parent_asin', 'title', 'average_rating', 'rating_number', 'price',
#        'store', 'description', 'image_url', 'categories', 'brand',
#        'unit_count', 'manufacturer', 'flavor', 'color'],
#       dtype='object')

# %%
# create a column called 'item' and 'category' from 'categories' and then remove 'categories'
df_sentiment['item'] = df_sentiment['categories'].str.split('>').str[-1].str.strip()
df_sentiment['category'] = df_sentiment['categories'].str.split('>').str[-2].str.strip()
df_sentiment = df_sentiment.drop('categories', axis=1)

df_sentiment.head(5)
# Out:
#   parent_asin                                              title  \
# 0  B00NE08WM6                             Dark Roast Pure Coffee
# 1  B084Q13Q5Q  PICARAS Galletas Peruanas Bañadas en Chocolate...
# 2  B00KBRUYVM  Chipped Beef and Gravy By Patterson's - Great ...
# 3  B0BN4PW255  Asher's Sugar Free Milk Chocolate Cordial Cher...
# 4  B06X9DC27H              Messmer Peppermint 25 bags (6er pack)
#
#    average_rating  rating_number  price       store  \
# 0             4.7              9    NaN    Luzianne
# 1             4.5             12  15.99     Winters
# 2             3.2              5    NaN  Pattersons
# 3             5.0              6  29.99     Generic
# 4             3.5              5  29.99     Messmer
#
#                                          description  \
# 0                                                NaN
# 1  2 Bags of PICARAS Galletas Bañadas en Chocolat...
# 2  Delicious corned beef gravy is ready when you ...
# 3                                                NaN
# 4                                                NaN
#
#                                            image_url     brand   unit_count  \
# 0  https://m.media-amazon.com/images/I/81ucKSAein...  Luzianne  13.00 Ounce
# 1  https://m.media-amazon.com/images/I/81-wr7u+ig...   Winters  12.00 Count
# 2  https://m.media-amazon.com/images/I/71MkAus3+q...       NaN          NaN
# 3                                                NaN   Generic   16.0 Ounce
# 4                                                NaN   Messmer   1.00 Count
#
#   manufacturer     flavor color       item    category
# 0          NaN        NaN   NaN     Coffee   Beverages
# 1     Winter's  chocolate   NaN  Chocolate     Cookies
# 2  Patterson's        NaN   NaN   Tomatoes  Vegetables
# 3          NaN  Chocolate   NaN      Fruit   Chocolate
# 4          NaN        NaN   NaN        NaN         NaN

# %%
# Get column names
cols = df_sentiment.columns.tolist()

# Rearrange: last two + everything else (put 'item' and 'category' in the start)
new_order = [cols[-2], cols[-1]] + cols[:-2]
df_sentiment = df_sentiment[new_order]

df_sentiment.head()
# Out:
#         item    category parent_asin  \
# 0     Coffee   Beverages  B00NE08WM6
# 1  Chocolate     Cookies  B084Q13Q5Q
# 2   Tomatoes  Vegetables  B00KBRUYVM
# 3      Fruit   Chocolate  B0BN4PW255
# 4        NaN         NaN  B06X9DC27H
#
#                                                title  average_rating  \
# 0                             Dark Roast Pure Coffee             4.7
# 1  PICARAS Galletas Peruanas Bañadas en Chocolate...             4.5
# 2  Chipped Beef and Gravy By Patterson's - Great ...             3.2
# 3  Asher's Sugar Free Milk Chocolate Cordial Cher...             5.0
# 4              Messmer Peppermint 25 bags (6er pack)             3.5
#
#    rating_number  price       store  \
# 0              9    NaN    Luzianne
# 1             12  15.99     Winters
# 2              5    NaN  Pattersons
# 3              6  29.99     Generic
# 4              5  29.99     Messmer
#
#                                          description  \
# 0                                                NaN
# 1  2 Bags of PICARAS Galletas Bañadas en Chocolat...
# 2  Delicious corned beef gravy is ready when you ...
# 3                                                NaN
# 4                                                NaN
#
#                                            image_url     brand   unit_count  \
# 0  https://m.media-amazon.com/images/I/81ucKSAein...  Luzianne  13.00 Ounce
# 1  https://m.media-amazon.com/images/I/81-wr7u+ig...   Winters  12.00 Count
# 2  https://m.media-amazon.com/images/I/71MkAus3+q...       NaN          NaN
# 3                                                NaN   Generic   16.0 Ounce
# 4                                                NaN   Messmer   1.00 Count
#
#   manufacturer     flavor color
# 0          NaN        NaN   NaN
# 1     Winter's  chocolate   NaN
# 2  Patterson's        NaN   NaN
# 3          NaN  Chocolate   NaN
# 4          NaN        NaN   NaN

# %%
print('Number of unique items:',df_sentiment['item'].nunique(),'\n')
df_sentiment['item'].unique()
# Out:
# Number of unique items: 779
# array(['Coffee', 'Chocolate', 'Tomatoes', 'Fruit', nan, 'Energy Drinks',
#        'Soups, Stocks & Broths', 'Hot Sauce',
#        'Single-Serve Capsules & Pods', 'Oatmeal', 'White',
#        'Food Coloring', 'Graham Crackers', 'Candy & Chocolate Gifts',
#        'Snack Gifts', 'Sea Salt', 'Candy & Chocolate Bars', 'Vegetable',
#        'Sour Candy', 'Stevia', 'Licorice', 'Dried Mixed Fruits',
#        'Candy & Chocolate Assortments', 'Sea Vegetables',
#        'Chips & Crisps', 'Mexican Seasoning', 'Instant Coffee',
#        'Potatoes & Yams', 'Green', 'Bloody Mary', 'Gummy Candy',
#        'Iced Tea', 'Ground Pepper', 'Tea Samplers', 'Hard Candy',
#        'Herb, Spice & Seasoning Gifts', 'Meat, Poultry & Seafood',
#        'Honey', 'Potato', 'Cake Toppers', 'Chewing & Bubble Gum',
#        'Ground Coffee', 'Sandwich', 'Mixed Nuts', 'Roasted Coffee Beans',
#        'Cakes', 'Mints', 'Matzo', 'Cocoa', 'Cold Cereals', 'Herbal',
#        'Ice Cream', 'Cookies', 'Pasta & Noodles', 'Peanuts',
#        'Candy & Chocolate', 'Meat Seasoning', 'Tenderloins', 'Wafers',
#        'Seaweed Snacks', 'Green Beans', 'Wheat', 'Peanut-Butter',
#        'Fruit Juice', 'Party Mix', 'Stewed', 'Deli & Prepared Foods',
#        'Sweet Pickles', 'Granola', 'Mixed Spices & Seasonings', 'Black',
#        'Ranch', 'Snack Foods', 'Breadcrumbs', 'Cilantro Flakes',
#        'Peppercorns', 'Cheese', 'Shortbread', 'Pesto', 'Parmesan',
#        'Mustard', 'Ketchup', 'Flavoring Powders', 'Pudding Mixes',
#        'Olive', 'Soft Drink Mixes', 'Soft Drinks', 'Cashews', 'Roasts',
#        'Side Dishes', 'Fruit Snacks', 'Bread & Dough', 'Breads',
#        'Mayonnaise', 'Pancakes & Waffles', 'Mineral Water', 'Cheddar',
#        'Steak Sauce', 'Quinoa', 'Pistachios', 'Bakery & Dessert Gifts',
#        'Bacon', 'Pumpkin Seeds', 'Flatbread', 'Candy Bars', 'Halibut',
#        'Pappardelle', 'Poultry Seasoning', 'Saltines',
#        'Bottled Beverages, Water & Drink Mixes', 'Dried Fruit & Raisins',
#        'Cereals', 'Nut Clusters', 'Cheese Blends', 'Hummus',
#        'Certified Organic Store', 'Macaroons', 'Jerky', 'Nuts', 'Oils',
#        'Chicken & Turkey', 'Fennel Seed', 'Almonds', 'High Protein',
#        'Pasta & Noodle Dishes', 'Meat & Seafood Gifts', 'Baguette',
#        'Syrups', 'Caviars & Roes', 'Flax Seed', 'Balsamic',
#        'Gourmet Rubs', 'Fruit Butters',
#        'Plant-Based Ice Cream & Novelties', 'Fresh Meal Kits',
#        'Yellow Mustard', 'Beer Brewing Recipe Kits',
#        'Suckers & Lollipops', 'Steaks', 'Anchovies', 'Chocolates',
#        'Sesame Seed', 'Meatballs, Chunks & Crumbles', 'Sunflower',
#        'Food Should Taste Good Multigrain Tortilla Free Sampling',
#        'Chocolate Chip', 'Dried Berries', 'Jasmine', 'Cranberries',
#        'Turkey', 'Rolls & Buns', 'Microwave', 'Layer Cakes',
#        'Icing Decorations', 'Vegetables', 'Iced Coffee & Cold-Brew',
#        'Jams, Jellies & Preserves', 'Celery', 'Toast',
#        'Single Herbs & Spices', 'Noodle Soups', 'Seasoned Rice',
#        'Chocolate Chips', 'Barbecue', 'Fruit Leather',
#        'Grocery Prime Day Meal Essentials', 'Macadamia Nuts',
#        'Seltzer Water', 'Stuffing Side Dishes', 'Onion', 'Pizza', 'Chai',
#        'Canned, Packaged & Baking', 'Teriyaki Sauce', 'Vanilla Beans',
#        'Ciders', 'Juices', 'Stews', 'English Mustard', 'Pasta & Sauces',
#        'Dried Dates', 'Shrimp & Prawns', 'Taffy', 'Roses',
#        'Herbs, Spices & Seasonings', 'Pie & Pastry Fillings', 'Tuna Fish',
#        'Apple Cider', 'Dried Figs', 'Tortilla', 'Cupcakes', 'Caesar',
#        'Kombucha', 'Breakfast & Cereal Bars', 'Carbonated Water',
#        'Caramels', 'Basmati', 'Coffee Substitutes', 'Bay Leaf',
#        'Seasoning Mixes', 'Bouillon', 'Italian', 'Fruit Bars', 'Salsas',
#        'Brown', 'Crackers', 'Macaroni & Cheese', 'Vegetable Soups',
#        'Cereal', 'Barbecue Seasoning', 'Chocolate Truffles', 'Corn',
#        'Coconut Water', 'Paprika', 'Feta', 'Croissants', 'Penne', 'Beef',
#        'Almond Butter', 'Nut Bars', 'Onions', 'Carob',
#        'Water Flavoring Drops', 'Wheat Cereals', 'Frozen Fish', 'Udon',
#        'Halva', 'Gouda', 'Basil', 'Pantry', 'Glitter',
#        'Wheat Flours & Meals', 'Puffed Snacks', 'Game Day Snacks',
#        'Apples', 'Sports Drinks', 'Snack & Trail Mixes', 'Pretzels',
#        'Sugars', 'Salad Dressings', 'Pita', 'Asian', 'Rice Dishes',
#        'Liquor Cakes', 'Spaghetti', 'Flavored Salt',
#        'Whole Foods Market - Pie toppings', 'Fruit & Nut', 'Baking Mixes',
#        'Breadsticks', 'Assortments & Variety Gifts', 'Rotini', 'Muesli',
#        'Coconut Flakes', 'Vinaigrette', 'Sprinkles', 'Mushrooms',
#        'Pink Lady', 'Buckwheat', 'Chili Sauce', 'Spiced Meat',
#        'Sandwiches & Wraps', 'Whole Wheat', 'Popcorn', 'Curry Sauce',
#        'Cookie Assortments', 'Pinto', 'Cloves', 'Cooking & Baking',
#        'Pineapple', 'Cumin', 'Rigatoni', 'Oysters', 'Sausage & Bacon',
#        'Beets', 'Marshmallows', 'Vegetable Relishes', 'Sugar Substitutes',
#        'Non-Stick Cooking Oil Sprays', 'Sourdough', 'Grapes', 'Truffle',
#        'Matcha', 'Active Dry Yeasts', 'Sauces', 'Natural', 'Deli Salads',
#        'Sunflower Seeds', 'Butter', 'Jelly Beans', 'Okra', 'Eggnog',
#        'Worcestershire Sauce', 'Water', 'White Granulated Sugar',
#        'Pickle Relishes', 'Baking Syrups, Sugars & Sweeteners', 'Nut',
#        'Popped', 'Smoked & Cured Fish', 'Saffron', 'Strip', 'Lentils',
#        'Fresh Fruits', 'Fruitcakes', 'Ham', 'Arrowroot',
#        'Food & Beverage Gifts', 'Beans & Peas', 'Beverages',
#        'Seasoned Salt', 'Sweet Basil Leaf', 'Grapeseed',
#        'Onions & Shallots', 'Meal Replacement Drinks', 'Fish Sauce',
#        'Pastries', 'Dijon Mustard', 'Ginger Candy', 'Fettuccine',
#        'Bitters', 'Adobo Sauce', 'Peaches', 'Indian Cuisine',
#        'Dill Pickles', 'Dill', 'Snack Packs & Lunches', 'Pot Pies',
#        'Biscotti', 'Jambalaya', 'Paleo-friendly foods',
#        'Leaveners & Yeasts', 'Spinach', 'Candy Canes', 'Baked Beans',
#        'Caramel', 'Fenugreek', 'Gourmet Holiday Guide', 'Dried Apricots',
#        'Sausages', 'Oat Bran', 'Wild Game & Fowl', 'Squash & Gourds',
#        'Bars', 'Lemonade', 'Cupcake Toppers', 'Grocery Prime Day Snacks',
#        'Brittle', 'Traditional Flavored', 'Gelatin',
#        'Canned, Jarred & Packaged Foods', 'Nuts & Seeds', 'Pasta',
#        'Potato Side Dishes', 'Kidney', 'Brazil Nuts',
#        'Assortments & Samplers', 'Garlic', 'Polenta Meal', 'Diced',
#        'Cornbread', 'Packaged Meals & Side Dishes',
#        'Gluten-Free Groceries', 'Simple Syrup', 'Kabobs', 'Sugar',
#        'Coconut', 'Herring', 'Chili Mix', 'Prepackaged Deli Meats',
#        'Meals & Entrees', 'Dairy Milk',
#        'Grocery Prime Day Cold Beverages', 'Sandwich Spreads', 'Tea',
#        'Thickeners', 'Grocery Prime Day Candy & Gum', 'Pies', 'Chips',
#        'Walnuts', 'Cream of Tartar', 'Sauce, Gravy & Marinade Gifts',
#        'Gravies', 'Black Beans', 'Ready to Drink Liquid Coffee',
#        'Vegetable Juice', 'Lager & Pilsner',
#        'Plant-Based Coffee Creamers', 'Almond Milk',
#        'Amazon Student Exclusive - 20% Off Groceries', 'Ghee', 'Papayas',
#        'Noodles', 'Cheese Assortments & Samplers', 'Shirataki',
#        'Sardines', 'Powdered', 'Snack Cakes', 'Pickles', 'Brownies',
#        'Popsicles & Juice Bars', 'Ice Cream & Novelties', 'Kumquats',
#        'Chocolate Drink Mixes', 'Fusilli', 'Guacamole', 'Bonsai',
#        'Festive Grocery', 'Maple Syrup', 'Pickled Mixed Vegetables',
#        'Processed', 'Donuts', 'Soy Sauce', 'French', 'Black Truffle',
#        'Dried Seaweed & Nori', 'Truffles', 'Fresh Fish', 'Lamb',
#        'Toaster Pastries', 'Unpopped', 'Dips & Spreads', 'Pasta Dishes',
#        'Entrees', 'Pie Shells & Crusts', 'Gluten free flavors',
#        'Jalapenos', 'Salmon', 'Tilapia', 'Plant-Based Lifestyles',
#        'Indian Seasoning', 'Marinara', 'Soba', 'Oolong',
#        'Dried Banana Chips',
#        'Whole Foods Market - Pumpkins, gourds and squash', 'Bagels',
#        'Protein Drinks', 'Hot Dog Buns', 'Chops', 'Burgers & Patties',
#        'Muffins & Quickbreads', 'Peanut Butter', 'Flavored Milk',
#        'Mushrooms & Truffles', 'Cherries', 'Danishes', 'Tomato Paste',
#        'Fruit & Nut Gifts', 'Olives', 'Coffeecakes', 'Chili Powder',
#        'Meatless', 'Powdered Sugar', 'Berries', 'Dry Soup Mixes',
#        'Dried Cherries', 'Cookie Dough', 'Unroasted Coffee Beans',
#        'Cocktail Mixers', 'Melon', 'Summer', 'Flours & Meals',
#        'Packaged Produce', 'Curry Powder', 'Pasta Salads', 'Ginger',
#        'Rice', 'Oregano', 'Turmeric', 'Black-Eyed Peas',
#        'Salt Substitutes', 'Tonic Water', 'Rice Cereals',
#        'Decorating Kits', 'String & Snack', 'Ground Beef', 'Vinegars',
#        'Pecans', 'Fresh Flowers & Live Indoor Plants', 'Pork Rinds',
#        'Rooibos', 'Oranges', 'Cucumbers', 'Fudge', 'Bow-Tie',
#        'Green Chilis', 'Snickerdoodles', 'Potatoes & Onion Rings',
#        'Millet', 'Restaurant and Bulk Food Supply', 'Dried Grains & Rice',
#        'Margarita', 'Salt & Salt Substitutes', 'Pork', 'Kids & Baby',
#        'Pizza Crust', 'Dried Prunes', 'Chorizo', 'Potatoes', 'Mangos',
#        'Smoothies', 'Flavored Water', 'Organic Groceries',
#        'Grocery Prime Day Baby Food & Formula', 'Whole Eggs', 'Broths',
#        'Imitation', 'Cardamom Seed', 'Sauerkraut', 'Pickled Eggs',
#        'Mussels & Cockles', 'Condensed',
#        'Dairy, Eggs & Plant-Based Alternatives', 'Artichoke Hearts',
#        'Cheese & Charcuterie Gifts', 'Jams, Jellies & Sweet Spreads',
#        'Frozen', 'Pudding & Gelatin', 'Paella', 'Savory',
#        'Ice Cream & Soft Serve Mixes', 'Spreads', 'Chocolate Eggs',
#        'Marzipan & Almond Paste', 'Breadcrumbs & Stuffing', 'Arborio',
#        'Mixed', 'Deli-Sliced Cheeses', 'Featured SNAP-eligible groceries',
#        'Agave Nectar & Syrup', 'Meat Substitutes', 'Tapioca',
#        'Marmalades', 'Chocolate & Hazelnut Spreads', 'Adobo Seasoning',
#        'Soy', 'Cheesecakes', 'A Taste of Summer', 'Dried Mushrooms',
#        'Cured Ham', 'Raisins', 'Grocery Fall Outlet', 'Holiday Entrees',
#        'Peeled', 'Chicken', 'Gourmet Foods', 'Bubble Tea Kits', 'Wild',
#        'Tuna', 'Tomato Sauce', 'Chia Seeds', 'Red', 'Panettones',
#        'Jam, Jelly & Sweet Spread Gifts', 'Fruits', 'Honey Mustard',
#        'Chocolate Blocks', 'Mixed Vegetables', 'Butterscotch Chips',
#        'Havarti', 'Hamburger Buns', 'Cashew Butter', 'Martini', 'Dates',
#        "Children's Cereals", 'Wheat Berries', 'Chutneys', 'Multigrain',
#        'Blue Cheese', 'Whole Foods Market - Classic holiday entrees',
#        'Grapefruit', 'Dried Cod', 'Refrigerated Doughs',
#        'Eggs & Egg Substitutes', 'Grocery Prime Day Deals',
#        'Dried Pineapples', 'Appetizers', 'Beer Brewing Ingredients',
#        'Apricots', 'Flatbreads', 'Whole Grain', 'Sparkling Juice',
#        'Limes', 'Vegetable Dishes', 'Frosting, Icing & Decorations',
#        'Xanthan Gum', 'Cut & Packaged Vegetables', 'Coconut Sauce',
#        'Tortillas', 'Capers', 'Glazes & Demi-Glaces', 'Ribeye',
#        'Sundried Tomatoes', 'Beans', 'Dried Vegetables', 'Chicken Soups',
#        'Pumpernickel', 'Ice Cream Cones & Toppings', 'Salad Toppings',
#        'Seafood Seasoning', 'Flavored', 'Sesame', 'Espresso Beans',
#        'Peppermint Leaf', 'Snails', 'Maple', 'Pizza Crusts', 'Pilaf',
#        'Pâtés', 'Tomato Soups', 'Lemon Grass', 'Coffee Creamers',
#        'Biscuits', 'Orzo', 'Water Chestnuts', 'Pears', 'Oat Milks',
#        'Nutmeg', 'Tea Gifts', 'Dusting Powders', 'Lobster', 'Applesauce',
#        'Breakfast Foods', 'Pantry Staples', 'Chili', 'Leafy Greens',
#        'Grits', 'Desserts & Toppings', 'Bubble Tea Tapioca Pearls',
#        'Shiitake', 'Crab Cakes', 'Hemp Seeds', 'Meat', 'Egg',
#        'Canned & Jarred Fish', 'Stir Fry Cuts', 'Rosemary',
#        'Dried Mangoes', 'Enchilada Sauce', 'Split Pea Soups',
#        'Burger Patties', 'Rock Salt', 'Miso Soups',
#        'Butter, Margarine & Plant-Based Alternatives', 'Sunflowers',
#        'Gelato', 'Oyster', 'Cinnamon', 'Italian Seasoning',
#        'Sandwich Breads', 'Juice', 'Pepper & Peppercorns',
#        'High Fiber Cereals', 'Naan', 'Fruit & Herbal Tea', 'Celery Seed',
#        'Xylitol', 'Processed Cheese', 'Vegetarian Proteins',
#        'Dried Coconut', 'Peanut', 'Sports Drinking Water', 'Beef Soups',
#        'Coconut Milk & Cream', 'Grocery Oatmeal Favorites',
#        'Powdered Drink Mixes & Flavorings', 'Instant Breakfast Drinks',
#        'Frozen Shellfish', 'Sage Leaf', 'Condiments & Salad Dressings',
#        'Parsley', 'Bamboo', 'Salami', 'Sloppy Joe Mix', 'Snack Pies',
#        'Rome', 'Cornichons', 'Rich Tea', 'Barley Flour', 'Cream Cheese',
#        'Cajun Seasoning', 'Casseroles, Pot Pies & Quiches', 'Pecorino',
#        'Figs', 'Garam Masala', 'Sourdough Starters', 'Chowders',
#        'Dried Fruits', 'Spices and seasonings', 'Red Wine', 'Fortune',
#        'Asian Cuisine', 'Strawberries', 'Sorbet & Sherbet',
#        'Breaded Mozzarella & Vegetables', 'Heavy Cream', 'Coffee Gifts',
#        'Hearts of Palm', 'Rye', 'Ginger Snaps', 'Sausage Snacks',
#        'Snacks', 'Fresh Vegetables', 'Deli Meats & Cheeses', 'Manchego',
#        'Bell Peppers', 'Ladyfingers', 'Bonito Flakes', 'Sesame Seeds',
#        'Portabello', 'Toffee', 'Almond', 'Kefir', 'Chili Peppers',
#        'Dinner Breads', 'Couscous', 'Tofu', 'Fennel', 'Chèvre',
#        'Stir-Fry Sauce', 'Brown Mustard', 'Latin Cuisine',
#        'Potash Baking Ingredient', 'Nuggets & Tenders', '1',
#        'Horseradish', 'Wasabi', 'Mixed Bouquets', 'Allspice',
#        'Dried Apples', 'Vegetarian', 'Carrots', 'Muffins', 'Fruit Cups',
#        'Weeknight Meal Solutions', 'Grocery Prime Day Baking',
#        'Seasoned Coatings', 'Alfredo', 'Deli Slices', 'Lard & Shortening',
#        'Garbanzo', 'Capellini', 'Ciabatta', 'Hazelnuts', 'Coarse Salt',
#        'Morel', 'Desserts', 'Orchids', 'Plant-Based Yogurt', 'Trout',
#        'Flavoring Syrup', 'Sausage', 'Packaged Greens & Salad Mixes',
#        'Dried Fruits & Vegetables', 'Swiss', 'Popcorn Salt',
#        'Stone Fruits', 'Hot Chocolate & Malted Drinks', 'German Mustard',
#        'Risotto', 'Dips, Salsas & Spreads', 'Maple Candy', 'Veal',
#        'Coriander', 'Brown Granulated Sugar', 'Bisques', 'Raspberry',
#        'Peanut Sauce', 'Egg Whites', 'Spinach & Greens',
#        'Dessert Syrups & Sauces', 'Cabbage', 'Mussels', 'Baking Powder',
#        'Seafood', 'Brie', 'Panko', 'Corn Starch', 'Sirloin'], dtype=object)

# %% [markdown]
# # Transactions Dataset --> for market basket analysis

# %%
# load the market basket dataset
df_market_basket = pd.read_csv('/content/Groceries_dataset.csv')
df_market_basket.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552    5/1/2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12/12/2015  other vegetables
# 4           3037    1/2/2015        whole milk

# %%
# unique items from the market basket dataset
print('Number of Unique Values in itemDescription', df_market_basket['itemDescription'].nunique())
print('Unique Values in itemDescription', df_market_basket['itemDescription'].unique())
# Out:
# Number of Unique Values in itemDescription 167
# Unique Values in itemDescription ['tropical fruit' 'whole milk' 'pip fruit' 'other vegetables' 'rolls/buns'
#  'pot plants' 'citrus fruit' 'beef' 'frankfurter' 'chicken' 'butter'
#  'fruit/vegetable juice' 'packaged fruit/vegetables' 'chocolate'
#  'specialty bar' 'butter milk' 'bottled water' 'yogurt' 'sausage'
#  'brown bread' 'hamburger meat' 'root vegetables' 'pork' 'pastry'
#  'canned beer' 'berries' 'coffee' 'misc. beverages' 'ham' 'turkey'
#  'curd cheese' 'red/blush wine' 'frozen potato products' 'flour' 'sugar'
#  'frozen meals' 'herbs' 'soda' 'detergent' 'grapes' 'processed cheese'
#  'fish' 'sparkling wine' 'newspapers' 'curd' 'pasta' 'popcorn'
#  'finished products' 'beverages' 'bottled beer' 'dessert' 'dog food'
#  'specialty chocolate' 'condensed milk' 'cleaner' 'white wine' 'meat'
#  'ice cream' 'hard cheese' 'cream cheese ' 'liquor' 'pickled vegetables'
#  'liquor (appetizer)' 'UHT-milk' 'candy' 'onions' 'hair spray'
#  'photo/film' 'domestic eggs' 'margarine' 'shopping bags' 'salt' 'oil'
#  'whipped/sour cream' 'frozen vegetables' 'sliced cheese' 'dish cleaner'
#  'baking powder' 'specialty cheese' 'salty snack' 'Instant food products'
#  'pet care' 'white bread' 'female sanitary products' 'cling film/bags'
#  'soap' 'frozen chicken' 'house keeping products' 'spread cheese'
#  'decalcifier' 'frozen dessert' 'vinegar' 'nuts/prunes' 'potato products'
#  'frozen fish' 'hygiene articles' 'artif. sweetener' 'light bulbs'
#  'canned vegetables' 'chewing gum' 'canned fish' 'cookware'
#  'semi-finished bread' 'cat food' 'bathroom cleaner' 'prosecco'
#  'liver loaf' 'zwieback' 'canned fruit' 'frozen fruits' 'brandy'
#  'baby cosmetics' 'spices' 'napkins' 'waffles' 'sauces' 'rum'
#  'chocolate marshmallow' 'long life bakery product' 'bags' 'sweet spreads'
#  'soups' 'mustard' 'specialty fat' 'instant coffee' 'snack products'
#  'organic sausage' 'soft cheese' 'mayonnaise' 'dental care'
#  'roll products ' 'kitchen towels' 'flower soil/fertilizer' 'cereals'
#  'meat spreads' 'dishes' 'male cosmetics' 'candles' 'whisky' 'tidbits'
#  'cooking chocolate' 'seasonal products' 'liqueur' 'abrasive cleaner'
#  'syrup' 'ketchup' 'cream' 'skin care' 'rubbing alcohol' 'nut snack'
#  'cocoa drinks' 'softener' 'organic products' 'cake bar' 'honey' 'jam'
#  'kitchen utensil' 'flower (seeds)' 'rice' 'tea' 'salad dressing'
#  'specialty vegetables' 'pudding powder' 'ready soups' 'make up remover'
#  'toilet cleaner' 'preservation products']

# %%
# number of rows in amazon meta dataset BEFORE mapping
df_sentiment.shape[0]
# Out:
# 5672

# %%
# keeping rows from sentiment dataset which has items from the market_basket data only

# Partial matching (if "Coffee" should match "coffee" or "instant coffee")
def matches_any(item, items_list):
    item_lower = str(item).lower()
    return any(item.lower() in item_lower or item_lower in item.lower()
               for item in items_list)

market_basket_items = df_market_basket['itemDescription'].unique()
df_sentiment = df_sentiment[df_sentiment['item'].apply(
    lambda x: matches_any(x, market_basket_items)
)]

# %%
# number of rows in amazon meta dataset AFTER mapping
df_sentiment.shape[0]
# Out:
# 1995

# %%
df_sentiment['item'].nunique()
# Out:
# 220

# %% [markdown]
# ### Create item_id to connect everything

# %%
# create item_id in both the dataset which will be used to link them

# Step 1: Get unique items and create ID mapping
unique_items = df_market_basket['itemDescription'].unique()
item_to_id = {item: idx for idx, item in enumerate(unique_items)}

# Step 2: Apply to df_market_basket
df_market_basket['item_id'] = df_market_basket['itemDescription'].map(item_to_id)

# Step 3: Apply to df_sentiment with partial matching
def get_item_id(item, item_dict, items_list):
    item_lower = str(item).lower()

    for basket_item in items_list:
        basket_lower = basket_item.lower()
        if basket_lower in item_lower or item_lower in basket_lower:
            return item_dict.get(basket_item)

    return None

df_sentiment['item_id'] = df_sentiment['item'].apply(
    lambda x: get_item_id(x, item_to_id, unique_items)
)

# %%
df_market_basket.head()
# Out:
#    Member_number        Date   itemDescription  item_id
# 0           1808  21-07-2015    tropical fruit        0
# 1           2552    5/1/2015        whole milk        1
# 2           2300  19-09-2015         pip fruit        2
# 3           1187  12/12/2015  other vegetables        3
# 4           3037    1/2/2015        whole milk        1

# %%
print('Unique Number of item_id in market_basket data: ', df_market_basket['item_id'].nunique())
print('Unique Number of item_id in sentiment data: ', df_sentiment['item_id'].nunique())
# Out:
# Unique Number of item_id in market_basket data:  167
# Unique Number of item_id in sentiment data:  67

# %%
df_sentiment.head(20)
# Out:
#                              item                 category parent_asin  \
# 0                          Coffee                Beverages  B00NE08WM6
# 1                       Chocolate                  Cookies  B084Q13Q5Q
# 3                           Fruit                Chocolate  B0BN4PW255
# 6          Soups, Stocks & Broths           Pantry Staples  B002HQF1BI
# 12                          White      Dried Grains & Rice  B0BYLK9168
# 14                Graham Crackers                 Crackers  B01GNI4V3E
# 16        Candy & Chocolate Gifts        Candy & Chocolate  B00LGZ6H3W
# 18                       Sea Salt  Salt & Salt Substitutes  B005GTTQMI
# 19                          Fruit                  Cookies  B01LF70OL6
# 20         Candy & Chocolate Bars                Chocolate  B07SFZTL7T
# 21                      Vegetable           Chips & Crisps  B00ZIG3DP0
# 22         Candy & Chocolate Bars                Chocolate  B0043GVCBI
# 23                     Sour Candy        Candy & Chocolate  B097NMZRBR
# 27                       Licorice        Candy & Chocolate  B0773JLNTD
# 32  Candy & Chocolate Assortments                Chocolate  B011JBS87K
# 36                 Instant Coffee                   Coffee  B01EM498G6
# 45                    Gummy Candy        Candy & Chocolate  B01LXZTQB1
# 46                       Iced Tea                      Tea  B0BB6CVPPM
# 49                   Tea Samplers                      Tea  B005SHMTKY
# 50                     Hard Candy        Candy & Chocolate  B0BMCND4LG
#
#                                                 title  average_rating  \
# 0                              Dark Roast Pure Coffee             4.7
# 1   PICARAS Galletas Peruanas Bañadas en Chocolate...             4.5
# 3   Asher's Sugar Free Milk Chocolate Cordial Cher...             5.0
# 6   Chincoteague Seafood 90944 Vegetable Red Crab ...             5.0
# 12  TAJ Indian Poha Powa Flattened Rice (Thick, 4-...             4.4
# 14  Glendee Toasted Coconut Chips,Honey, 1.41 Ounc...             2.0
# 16  Strawberry Delights Hard Candy, 3 lb Bag in a ...             3.9
# 18  Eden Organic Gomasio, Sesame Seeds and Sea Sal...             4.4
# 19  Newtons Fat Free Soft & Fruit Chewy Fig Cookie...             4.5
# 20  Godiva Chocolatier Assorted Chocolate Advent C...             4.1
# 21  Peeled Snacks Organic Peas Please, Southwest S...             3.4
# 22  CANDY MILKWAY DRK1.76OZ by MILKY WAY MfrPartNo...             4.7
# 23  Cherry Sours Chewy Candy Balls - 3 lbs of Tart...             4.2
# 27  Twizzlers Strawberry Twizzlers Licorice (2 lb....             3.4
# 32  Nucita Trisabor Mexican Candy 3 Flavors Chocol...             4.6
# 36                  DXN Vita Cafe 6 in 1 (Pack of 20)             4.7
# 45  Haribo Halloween Sweet or Scary Mix, 11.85 oz ...             4.6
# 46  4C Green Tea Antioxidant Iced Tea Mix | Family...             4.6
# 49   MIGHTY LEAF Organic Ginger Peach Iced Tea, 21 CT             4.7
# 50  Filled Raspberries - 1.5 lbs of Individually S...             4.8
#
#     rating_number  price                 store  \
# 0               9    NaN              Luzianne
# 1              12  15.99               Winters
# 3               6  29.99               Generic
# 6               2  73.57  Chincoteague Seafood
# 12            203  17.99     TAJ Gourmet Foods
# 14              2    NaN               Glendee
# 16              8  14.99  Black Tie Mercantile
# 18            157   9.99                  Eden
# 19           1022   4.59           Fig Newtons
# 20             88    NaN    Godiva Chocolatier
# 21            158    NaN         Peeled Snacks
# 22             25  39.95                   NaN
# 23            474    NaN        Emporium Candy
# 27              7    NaN             Twizzlers
# 32              6    NaN                   NaN
# 36            503  22.31                   DXN
# 45             66    NaN                Haribo
# 46            514  25.15                    4c
# 49             18    NaN           Mighty Leaf
# 50             10    NaN             DM Sweets
#
#                                           description  \
# 0                                                 NaN
# 1   2 Bags of PICARAS Galletas Bañadas en Chocolat...
# 3                                                 NaN
# 6   Vegetable Red Crab Soup is a colorful combinat...
# 12    TAJ Gourmet Foods provides the best of quality.
# 14  Coconut chips are a healthy snack with all the...
# 16  About This BlackTie Box: | Introducing the Bla...
# 18                                                NaN
# 19  Newtons Fat Free Soft and Fruit Chewy Fig Cook...
# 20  Let the countdown begin this gorgeous chocolat...
# 21  Product Description | We believe you should fe...
# 22                                                NaN
# 23  Sour Cherry Chewy Candy Balls - 3 lbs of Tart ...
# 27                                                NaN
# 32                                                NaN
# 36  The uniqueness of DXN Vita Cafe! An exclusive ...
# 45  Have the best house on the block with HARIBO’s...
# 46  4C Foods is a family owned business since 1935...
# 49  Save on Mighty Leaf Tea Peach. Made from Black...
# 50  Filled Raspberries - 1.5 lbs of Individually W...
#
#                                             image_url                 brand  \
# 0   https://m.media-amazon.com/images/I/81ucKSAein...              Luzianne
# 1   https://m.media-amazon.com/images/I/81-wr7u+ig...               Winters
# 3                                                 NaN               Generic
# 6                                                 NaN  Chincoteague Seafood
# 12  https://m.media-amazon.com/images/I/81gnkkdr8b...     TAJ Gourmet Foods
# 14  https://m.media-amazon.com/images/I/51E98OgptJ...                   NaN
# 16  https://m.media-amazon.com/images/I/81sAsNh8lY...                   NaN
# 18  https://m.media-amazon.com/images/I/71XkGm3Jpy...                  Eden
# 19  https://m.media-amazon.com/images/I/81Tex99-ig...                   NaN
# 20  https://m.media-amazon.com/images/I/710khhpkRz...                   NaN
# 21  https://m.media-amazon.com/images/I/611kSL8C8O...                   NaN
# 22                                                NaN                   NaN
# 23  https://m.media-amazon.com/images/I/815qJBUBcg...        Emporium Candy
# 27  https://m.media-amazon.com/images/I/71GWM1pwCb...             Twizzlers
# 32                                                NaN                   NaN
# 36  https://m.media-amazon.com/images/I/61LRBjhrDf...                   DXN
# 45  https://m.media-amazon.com/images/I/71O4iNGSDZ...                Haribo
# 46  https://m.media-amazon.com/images/I/7119Ivj49X...                   NaN
# 49  https://m.media-amazon.com/images/I/71PpO4Y+41...                   NaN
# 50  https://m.media-amazon.com/images/I/918TJfg1Gm...             DM Sweets
#
#      unit_count             manufacturer              flavor color  item_id
# 0   13.00 Ounce                      NaN                 NaN   NaN       26
# 1   12.00 Count                 Winter's           chocolate   NaN       13
# 3    16.0 Ounce                      NaN           Chocolate   NaN        0
# 6           NaN     Chincoteague Seafood            Red Crab   NaN      121
# 12   1.00 Count        TAJ Gourmet Foods                 NaN   NaN       55
# 14          NaN                  Glendee                 NaN   NaN       28
# 16          NaN     Black Tie Mercantile                 NaN   NaN       13
# 18          NaN               Eden Foods              Savory   NaN       71
# 19          NaN         Mondelez Int. US                 NaN   NaN        0
# 20          NaN           AmazonUs/GODMS                 NaN   NaN       13
# 21          NaN            Peeled Snacks                 NaN   NaN        3
# 22   1.76 ounce                      NaN                 NaN   NaN       13
# 23     48 Fl Oz           Emporium Candy              Cherry   NaN       64
# 27   33.3 Ounce                      NaN          Strawberry   NaN      158
# 32          NaN                      NaN             Vanilla   NaN       13
# 36          NaN                      DXN                cafe   NaN       26
# 45  142.2 Ounce  Haribo of America, Inc.  Sweet or Scary Mix   NaN       64
# 46          NaN                       4C                 NaN   NaN      159
# 49          NaN              MIGHTY LEAF                 NaN   NaN      159
# 50   24.0 Ounce                      NaN           Raspberry   NaN       64

# %%
# all different types of coffee are under the same item_id
print(df_sentiment[df_sentiment['item_id'] == 26])
# Out:
#                       item            category parent_asin  \
# 0                   Coffee           Beverages  B00NE08WM6
# 36          Instant Coffee              Coffee  B01EM498G6
# 61           Ground Coffee              Coffee  B00AI13WJW
# 67    Roasted Coffee Beans  Whole Coffee Beans  B0091YJHUU
# 103         Instant Coffee              Coffee  B00GAT2ZRQ
# ...                    ...                 ...         ...
# 6044         Ground Coffee              Coffee  B000209K22
# 6059                Coffee           Beverages  B07QLYCTHC
# 6138        Instant Coffee              Coffee  B0BCMBGFFM
# 6185         Ground Coffee              Coffee  B00GXOQUDI
# 6213         Ground Coffee              Coffee  B009LI7O2E
#
#                                                   title  average_rating  \
# 0                                Dark Roast Pure Coffee             4.7
# 36                    DXN Vita Cafe 6 in 1 (Pack of 20)             4.7
# 61    Coffee Fool's Ethiopian Yirgacheffe (Coarse Gr...             3.1
# 67    Starbucks Medium Roast Whole Bean Coffee — Bre...             4.7
# 103   Victorian Inn Instant Cappuccino, Reduced Suga...             3.9
# ...                                                 ...             ...
# 6044  Green Mountain Coffee Fair Trade Organic House...             3.6
# 6059   Cafe Femenino Organic Whole Bean Espresso, 12 OZ             4.0
# 6138  Maxwell House - International Latte (Pumpkin S...             4.6
# 6185  Blue Mountain Gold Blue Mountain Ground Bean C...             3.0
# 6213  Millstone 100% Colombian Coffee, 11 Ounce (Pac...             4.1
#
#       rating_number  price                           store  \
# 0                 9    NaN                        Luzianne
# 36              503  22.31                             DXN
# 61                3  10.29                 The Coffee Fool
# 67             7794    NaN                       Starbucks
# 103              14  31.46                   Victorian Inn
# ...             ...    ...                             ...
# 6044             22    NaN  Green Mountain Coffee Roasters
# 6059              7    NaN                   Cafe Femenino
# 6138           9124    NaN                   MAXWELL HOUSE
# 6185              4    NaN              BLUE MOUNTAIN GOLD
# 6213              5    NaN                       Millstone
#
#                                             description  \
# 0                                                   NaN
# 36    The uniqueness of DXN Vita Cafe! An exclusive ...
# 61    Spicy, fragrant and as exotic as its name. Yir...
# 67    We introduced this blend in 1998 for those who...
# 103                                                 NaN
# ...                                                 ...
# 6044  Product Description | The cornerstone of our F...
# 6059                                             Coffee
# 6138                                                NaN
# 6185                                                NaN
# 6213                                                NaN
#
#                                               image_url               brand  \
# 0     https://m.media-amazon.com/images/I/81ucKSAein...            Luzianne
# 36    https://m.media-amazon.com/images/I/61LRBjhrDf...                 DXN
# 61    https://m.media-amazon.com/images/I/71bBE+yO3i...                 NaN
# 67    https://m.media-amazon.com/images/I/71-8RChG+T...                 NaN
# 103   https://m.media-amazon.com/images/I/61CuTcTPpp...                 NaN
# ...                                                 ...                 ...
# 6044  https://m.media-amazon.com/images/I/81901-WKrj...                 NaN
# 6059  https://m.media-amazon.com/images/I/51u5KaOrf+...                 NaN
# 6138  https://m.media-amazon.com/images/I/81mOWXUhi8...       MAXWELL HOUSE
# 6185  https://m.media-amazon.com/images/I/91CLmcEF+2...  BLUE MOUNTAIN GOLD
# 6213  https://m.media-amazon.com/images/I/81Wzew1szx...                 NaN
#
#        unit_count           manufacturer         flavor color  item_id
# 0     13.00 Ounce                    NaN            NaN   NaN       26
# 36            NaN                    DXN           cafe   NaN       26
# 61            NaN        The Coffee Fool            NaN   NaN       26
# 67            NaN              Starbucks            NaN   NaN       26
# 103           NaN      United Food Group            NaN   NaN       26
# ...           ...                    ...            ...   ...      ...
# 6044          NaN  Green Mountain Coffee            NaN   NaN       26
# 6059          NaN          Cafe Femenino            NaN   NaN       26
# 6138          NaN            Kraft Foods  Pumpkin Spice   NaN       26
# 6185     32 Ounce                    NaN           Bean   NaN       26
# 6213          NaN   The J.M. Smucker Co.            NaN   NaN       26
#
# [238 rows x 16 columns]

# %%
df_sentiment.columns
# Out:
# Index(['item', 'category', 'parent_asin', 'title', 'average_rating',
#        'rating_number', 'price', 'store', 'description', 'image_url', 'brand',
#        'unit_count', 'manufacturer', 'flavor', 'color', 'item_id'],
#       dtype='object')

# %%
# creating different dfs to create tables
df_product = df_sentiment[['item_id', 'item', 'category']]
df_ratings = df_sentiment[['item_id', 'parent_asin', 'average_rating', 'rating_number']] # add from other reviews dataset using 'parent_asin'
df_product_details = df_sentiment[['item_id', 'title',
        'price', 'store', 'description', 'image_url', 'brand',
        'unit_count', 'manufacturer', 'flavor', 'color']]

# remove duplicates of item_id
df_product = df_product.drop_duplicates(subset='item_id')
df_product_details = df_product_details.drop_duplicates(subset='item_id')

# %% [markdown]
# ### linking via 'item_id'
# * product -- ratings
# * product -- product_details
# * ratings -- product_details

# %%
df_product.head()
# Out:
#     item_id                    item             category
# 0        26                  Coffee            Beverages
# 1        13               Chocolate              Cookies
# 3         0                   Fruit            Chocolate
# 6       121  Soups, Stocks & Broths       Pantry Staples
# 12       55                   White  Dried Grains & Rice

# %%
df_ratings.head()
# Out:
#     item_id parent_asin  average_rating  rating_number
# 0        26  B00NE08WM6             4.7              9
# 1        13  B084Q13Q5Q             4.5             12
# 3         0  B0BN4PW255             5.0              6
# 6       121  B002HQF1BI             5.0              2
# 12       55  B0BYLK9168             4.4            203

# %%
df_product_details.head()
# Out:
#     item_id                                              title  price  \
# 0        26                             Dark Roast Pure Coffee    NaN
# 1        13  PICARAS Galletas Peruanas Bañadas en Chocolate...  15.99
# 3         0  Asher's Sugar Free Milk Chocolate Cordial Cher...  29.99
# 6       121  Chincoteague Seafood 90944 Vegetable Red Crab ...  73.57
# 12       55  TAJ Indian Poha Powa Flattened Rice (Thick, 4-...  17.99
#
#                    store                                        description  \
# 0               Luzianne                                                NaN
# 1                Winters  2 Bags of PICARAS Galletas Bañadas en Chocolat...
# 3                Generic                                                NaN
# 6   Chincoteague Seafood  Vegetable Red Crab Soup is a colorful combinat...
# 12     TAJ Gourmet Foods    TAJ Gourmet Foods provides the best of quality.
#
#                                             image_url                 brand  \
# 0   https://m.media-amazon.com/images/I/81ucKSAein...              Luzianne
# 1   https://m.media-amazon.com/images/I/81-wr7u+ig...               Winters
# 3                                                 NaN               Generic
# 6                                                 NaN  Chincoteague Seafood
# 12  https://m.media-amazon.com/images/I/81gnkkdr8b...     TAJ Gourmet Foods
#
#      unit_count          manufacturer     flavor color
# 0   13.00 Ounce                   NaN        NaN   NaN
# 1   12.00 Count              Winter's  chocolate   NaN
# 3    16.0 Ounce                   NaN  Chocolate   NaN
# 6           NaN  Chincoteague Seafood   Red Crab   NaN
# 12   1.00 Count     TAJ Gourmet Foods        NaN   NaN

# %% [markdown]
# # Amazon Reviews Dataset --> for sentiment analysis

# %%
# load the reviews dataset for sentiment analysis
df_sentiment_reviews = pd.read_csv('/content/Reviews_Grocery_and_Gourmet_Food.csv')
df_sentiment_reviews.head()
# Out:
#    rating                                   title  \
# 0     5.0                      Excellent!  Yummy!
# 1     5.0                       Delicious!!! Yum!
# 2     5.0  Extremely Delicious, but expensive imo
# 3     5.0                              Delicious!
# 4     5.0                             Great taste
#
#                                                 text images        asin  \
# 0  Excellent!! Yummy!  Great with other foods and...    NaN  B00CM36GAQ
# 1  Excellent!  The best!  I use it with my beef a...    NaN  B074J5WVYH
# 2  These are very tasty. They are extremely soft ...    NaN  B079TRNVHX
# 3                                       My favorite!    NaN  B07194LN2Z
# 4     Great for making brownies and crinkle cookies.    NaN  B005CD4196
#
#   parent_asin                       user_id     timestamp verified_purchase  \
# 0  B00CM36GAQ  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1.587854e+12              True
# 1  B0759B7KLH  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1.587854e+12              True
# 2  B079TRNVHX  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1.587853e+12              True
# 3  B07194LN2Z  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1.581313e+12              True
# 4  B005CD4196  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1.581313e+12              True
#
#    helpful_vote
# 0           0.0
# 1           0.0
# 2           1.0
# 3           0.0
# 4           7.0

# %%
df_sentiment_reviews.shape # full data (7082832, 10)
# Out:
# (20011, 10)

# %%
df_sentiment_reviews.isna().sum()
# Out:
# rating                   0
# title                    0
# text                     1
# images               19439
# asin                     1
# parent_asin              1
# user_id                  1
# timestamp                1
# verified_purchase        1
# helpful_vote             1
# dtype: int64

# %%
# drop 'images' column since most are null
df_sentiment_reviews = df_sentiment_reviews.drop('images', axis=1)
df_sentiment_reviews.columns
# Out:
# Index(['rating', 'title', 'text', 'asin', 'parent_asin', 'user_id',
#        'timestamp', 'verified_purchase', 'helpful_vote'],
#       dtype='object')

# %%
df_sentiment_reviews['verified_purchase'].unique()
# Out:
# array([True, False, nan], dtype=object)

# %%
# keep rows where 'verified_purchase' == 'TRUE' as those are the only people who bought the product
# 'verified_purchase' == 'FALSE' means did not buy product
df_sentiment_reviews = df_sentiment_reviews[df_sentiment_reviews['verified_purchase'] == True]
df_sentiment_reviews['verified_purchase'].unique()
# Out:
# array([True], dtype=object)

# %%
df_sentiment_reviews.shape
# Out:
# (16089, 9)

# %%
df_sentiment_reviews.head()
# Out:
#    rating                                   title  \
# 0     5.0                      Excellent!  Yummy!
# 1     5.0                       Delicious!!! Yum!
# 2     5.0  Extremely Delicious, but expensive imo
# 3     5.0                              Delicious!
# 4     5.0                             Great taste
#
#                                                 text        asin parent_asin  \
# 0  Excellent!! Yummy!  Great with other foods and...  B00CM36GAQ  B00CM36GAQ
# 1  Excellent!  The best!  I use it with my beef a...  B074J5WVYH  B0759B7KLH
# 2  These are very tasty. They are extremely soft ...  B079TRNVHX  B079TRNVHX
# 3                                       My favorite!  B07194LN2Z  B07194LN2Z
# 4     Great for making brownies and crinkle cookies.  B005CD4196  B005CD4196
#
#                         user_id     timestamp verified_purchase  helpful_vote
# 0  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1.587854e+12              True           0.0
# 1  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1.587854e+12              True           0.0
# 2  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1.587853e+12              True           1.0
# 3  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1.581313e+12              True           0.0
# 4  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  1.581313e+12              True           7.0

# %%
df_sentiment_reviews.shape
# Out:
# (16089, 9)

# %%
df_sentiment_reviews[['parent_asin','asin']].nunique()
# Out:
# parent_asin    10506
# asin           12028
# dtype: int64

# %%
# figuring out PK for reviews --> user_id + parent_asin + asin

# df_sentiment_reviews1 = df_sentiment_reviews.copy()
# df_sentiment_reviews1['user_id_parent_asin_asin_combine'] = df_sentiment_reviews['user_id'] + '_' + df_sentiment_reviews['parent_asin']+ '_' + df_sentiment_reviews['asin']
# df_sentiment_reviews1['user_id_parent_asin_asin_combine'].nunique()
# df_sentiment_reviews1.head()

# %%
# Remove database .bd file if it already exists in collab
import shutil
shutil.rmtree('/content/spark-warehouse/products.db', ignore_errors=True)

# %% [markdown]
# # Create a dataframe for customers using Faker

# %%
# !pip install faker
# Out:
# Requirement already satisfied: faker in /usr/local/lib/python3.12/dist-packages (38.2.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from faker) (2025.2)

# %%
from faker import Faker
import pandas as pd
import random

# Initialize Faker
fake = Faker()

# Get unique user_ids from reviews dataset
unique_user_ids = df_sentiment_reviews['user_id'].unique()

# Create lists for fake data
first_names = []
last_names = []
ages = []

# Generate fake data for each unique user_id
for _ in range(len(unique_user_ids)):
    first_names.append(fake.first_name())
    last_names.append(fake.last_name())
    ages.append(random.randint(10, 100))

# Create the customer DataFrame
df_customer = pd.DataFrame({
    'user_id': unique_user_ids,
    'first_name': first_names,
    'last_name': last_names,
    'age': ages
})

# View the result
print(df_customer.head())
# Out:
#                         user_id first_name last_name  age
# 0  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ  Alexandra    Gibson   29
# 1  AGGZ357AO26RQZVRLGU4D4N52DZQ      Karen    Wilson   74
# 2  AG2L7H23R5LLKDKLBEF2Q3L2MVDA       Kyle    Burton   87
# 3  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ    Jeffrey    Berger   42
# 4  AGXVBIUFLFGMVLATYXHJYL4A5Q7Q      Brian    Bowers   57

# %% [markdown]
# ### Create a database with tables from all the above three dataframes

# %%
# ALL DATASETS COMBINED INTO ONE DATABASE AS INDIVIDUAL TABLES
from pyspark.sql import SparkSession

# Step 1: Initialize Spark session
spark = SparkSession.builder \
    .appName("Creating Databases") \
    .getOrCreate()

# Step 2: Create the database
spark.sql("CREATE DATABASE IF NOT EXISTS Products")

# Step 3: Convert pandas DataFrames to PySpark DataFrames
df_transaction_spark = spark.createDataFrame(df_market_basket)
df_product_spark = spark.createDataFrame(df_product)
df_ratings_spark = spark.createDataFrame(df_ratings)
df_sentiment_reviews_spark = spark.createDataFrame(df_sentiment_reviews)
df_product_details_spark = spark.createDataFrame(df_product_details)
df_customer_spark = spark.createDataFrame(df_customer)

# # Merge df_sentiment_reviews with df_ratings on 'parent_asin'
# df_reviews_combined = df_ratings.merge(
#     df_sentiment_reviews,
#     on='parent_asin',
#     how='left'  # Use 'inner' if you only want matching rows
# )

# Step 4: Rename 'itemDescription' column in the transactions table to 'item' to keep it similar to products table
df_transaction_spark = df_transaction_spark.withColumnRenamed('itemDescription', 'item')


# Step 5: Save tables to the Products database
df_transaction_spark.write.mode("overwrite").saveAsTable("Products.transactions")
df_product_spark.write.mode("overwrite").saveAsTable("Products.product")
df_ratings_spark.write.mode("overwrite").saveAsTable("Products.ratings")
df_sentiment_reviews_spark.write.mode("overwrite").saveAsTable("Products.reviews")
df_product_details_spark.write.mode("overwrite").saveAsTable("Products.product_details")
df_customer_spark.write.mode("overwrite").saveAsTable("Products.customer")


# Step 6: Verify tables were created
spark.sql("SHOW TABLES IN Products").show()

# Step 7: Query the tables
print("=== CUSTOMER TABLE ===")
spark.sql("SELECT * FROM Products.customer LIMIT 10").show()

print("=== PRODUCT TABLE ===")
spark.sql("SELECT * FROM Products.product LIMIT 10").show()
#
print("\n=== PRODUCT DETAILS TABLE ===")
spark.sql("SELECT * FROM Products.product_details LIMIT 10").show()

print("\n=== RATINGS TABLE ===")
spark.sql("SELECT * FROM Products.ratings LIMIT 10").show()

print("\n=== REVIEWS TABLE ===")
spark.sql("SELECT * FROM Products.reviews LIMIT 10").show()

print("\n=== TRANSACTIONS TABLE ===")
spark.sql("SELECT * FROM Products.transactions LIMIT 10").show()
# Out:
# +---------+--------------------+-----------+
# |namespace|           tableName|isTemporary|
# +---------+--------------------+-----------+
# | products|            customer|      false|
# | products|             product|      false|
# | products|     product_details|      false|
# | products|             ratings|      false|
# | products|             reviews|      false|
# | products|        transactions|      false|
# |         |       temp_customer|       true|
# |         |        temp_product|       true|
# |         |temp_product_details|       true|
# |         |        temp_ratings|       true|
# |         |        temp_reviews|       true|
# |         |   temp_transactions|       true|
# +---------+--------------------+-----------+
#
# === CUSTOMER TABLE ===
# +--------------------+----------+---------+---+
# |             user_id|first_name|last_name|age|
# +--------------------+----------+---------+---+
# |AHNTBBOCVJSXTQ7SB...|     Linda|   Keller| 64|
# |AGM3YP753ITBWIEJ7...|    Angela|  Mcgrath| 35|
# |AEIMSJ6H563BKNO2O...|    Rachel|     Hart| 50|
# |AHD5DXKPN6RBJFDJT...|    Brandy|    Scott| 20|
# |AGB7TRSICVT7ORW66...|     Alice|   Brooks| 63|
# |AELHB5QYXVSXZM263...|   Zachary|     Ward| 77|
# |AFHO7OBEBKY4YNEFO...|      Lynn|    Reyes| 78|
# |AF34HQQ3RZOFQDNN6...|    Joseph|   Molina| 63|
# |AEZV3WDCDM6V4CJMN...|     Emily|  Shelton| 26|
# |AE5VGVXXG4YF6JKFP...|   Charles|Schneider| 45|
# +--------------------+----------+---------+---+
#
# === PRODUCT TABLE ===
# +-------+--------------------+--------------------+
# |item_id|                item|            category|
# +-------+--------------------+--------------------+
# |     25|       Dried Berries|        Dried Fruits|
# |     29|              Turkey|      Meat & Seafood|
# |    155|Jams, Jellies & P...|Jams, Jellies & S...|
# |     36|Single Herbs & Sp...|Herbs, Spices & S...|
# |     65|               Onion|Single Herbs & Sp...|
# |     23|Pie & Pastry Fill...|    Cooking & Baking|
# |     41|           Tuna Fish|             Seafood|
# |     19|               Brown| Dried Grains & Rice|
# |     46|                Corn|      Chips & Crisps|
# |      7|                Beef|              Broths|
# +-------+--------------------+--------------------+
#
#
# === PRODUCT DETAILS TABLE ===
# +-------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+----------+-----+
# |item_id|               title|price|               store|         description|           image_url|               brand| unit_count|        manufacturer|    flavor|color|
# +-------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+----------+-----+
# |     26|Dark Roast Pure C...|  NaN|            Luzianne|                 NaN|https://m.media-a...|            Luzianne|13.00 Ounce|                 NaN|       NaN|  NaN|
# |     13|PICARAS Galletas ...|15.99|             Winters|2 Bags of PICARAS...|https://m.media-a...|             Winters|12.00 Count|            Winter's| chocolate|  NaN|
# |      0|Asher's Sugar Fre...|29.99|             Generic|                 NaN|                 NaN|             Generic| 16.0 Ounce|                 NaN| Chocolate|  NaN|
# |    121|Chincoteague Seaf...|73.57|Chincoteague Seafood|Vegetable Red Cra...|                 NaN|Chincoteague Seafood|        NaN|Chincoteague Seafood|  Red Crab|  NaN|
# |     55|TAJ Indian Poha P...|17.99|   TAJ Gourmet Foods|TAJ Gourmet Foods...|https://m.media-a...|   TAJ Gourmet Foods| 1.00 Count|   TAJ Gourmet Foods|       NaN|  NaN|
# |     28|Glendee Toasted C...|  NaN|             Glendee|Coconut chips are...|https://m.media-a...|                 NaN|        NaN|             Glendee|       NaN|  NaN|
# |     71|Eden Organic Goma...| 9.99|                Eden|                 NaN|https://m.media-a...|                Eden|        NaN|          Eden Foods|    Savory|  NaN|
# |      3|Peeled Snacks Org...|  NaN|       Peeled Snacks|Product Descripti...|https://m.media-a...|                 NaN|        NaN|       Peeled Snacks|       NaN|  NaN|
# |     64|Cherry Sours Chew...|  NaN|      Emporium Candy|Sour Cherry Chewy...|https://m.media-a...|      Emporium Candy|   48 Fl Oz|      Emporium Candy|    Cherry|  NaN|
# |    158|Twizzlers Strawbe...|  NaN|           Twizzlers|                 NaN|https://m.media-a...|           Twizzlers| 33.3 Ounce|                 NaN|Strawberry|  NaN|
# +-------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+----------+-----+
#
#
# === RATINGS TABLE ===
# +-------+-----------+--------------+-------------+
# |item_id|parent_asin|average_rating|rating_number|
# +-------+-----------+--------------+-------------+
# |     26| B00NE08WM6|           4.7|            9|
# |     13| B084Q13Q5Q|           4.5|           12|
# |      0| B0BN4PW255|           5.0|            6|
# |    121| B002HQF1BI|           5.0|            2|
# |     55| B0BYLK9168|           4.4|          203|
# |     28| B01GNI4V3E|           2.0|            2|
# |     13| B00LGZ6H3W|           3.9|            8|
# |     71| B005GTTQMI|           4.4|          157|
# |      0| B01LF70OL6|           4.5|         1022|
# |     13| B07SFZTL7T|           4.1|           88|
# +-------+-----------+--------------+-------------+
#
#
# === REVIEWS TABLE ===
# +------+--------------------+--------------------+----------+-----------+--------------------+-----------------+-----------------+------------+
# |rating|               title|                text|      asin|parent_asin|             user_id|        timestamp|verified_purchase|helpful_vote|
# +------+--------------------+--------------------+----------+-----------+--------------------+-----------------+-----------------+------------+
# |   5.0|  Excellent!  Yummy!|Excellent!! Yummy...|B00CM36GAQ| B00CM36GAQ|AFKZENTNBQ7A7V7UX...|1.587854482395E12|             true|         0.0|
# |   5.0|   Delicious!!! Yum!|Excellent!  The b...|B074J5WVYH| B0759B7KLH|AFKZENTNBQ7A7V7UX...| 1.58785440038E12|             true|         0.0|
# |   5.0|Extremely Delicio...|These are very ta...|B079TRNVHX| B079TRNVHX|AFKZENTNBQ7A7V7UX...|1.587853224527E12|             true|         1.0|
# |   5.0|          Delicious!|        My favorite!|B07194LN2Z| B07194LN2Z|AFKZENTNBQ7A7V7UX...|1.581313319614E12|             true|         0.0|
# |   5.0|         Great taste|Great for making ...|B005CD4196| B005CD4196|AFKZENTNBQ7A7V7UX...|1.581313294965E12|             true|         7.0|
# |   5.0|              Yummy!|Yummy for your tu...|B07R2X568B| B0BG8M4XW7|AFKZENTNBQ7A7V7UX...|1.581313263026E12|             true|         0.0|
# |   5.0|Excellent tea & s...|This is an excell...|B07LDF9V2F| B07VV7T465|AFKZENTNBQ7A7V7UX...| 1.55287848355E12|             true|         0.0|
# |   5.0|Like drinking a w...|This is my #1 fav...|B000OQXXOA| B00ESE0DC4|AFKZENTNBQ7A7V7UX...|1.552878387841E12|             true|         0.0|
# |   5.0|          Delicious!|I was never a hug...|B073DCD5GC| B073DDP593|AFKZENTNBQ7A7V7UX...|1.552878262155E12|             true|         1.0|
# |   5.0|Yummy tea with a ...|The tea is very g...|B009PO1JTS| B009PO1JTS|AFKZENTNBQ7A7V7UX...| 1.55287820886E12|             true|         0.0|
# +------+--------------------+--------------------+----------+-----------+--------------------+-----------------+-----------------+------------+
#
#
# === TRANSACTIONS TABLE ===
# +-------------+----------+----------------+-------+
# |Member_number|      Date|            item|item_id|
# +-------------+----------+----------------+-------+
# |         1808|21-07-2015|  tropical fruit|      0|
# |         2552|  5/1/2015|      whole milk|      1|
# |         2300|19-09-2015|       pip fruit|      2|
# |         1187|12/12/2015|other vegetables|      3|
# |         3037|  1/2/2015|      whole milk|      1|
# |         4941|14-02-2015|      rolls/buns|      4|
# |         4501|  8/5/2015|other vegetables|      3|
# |         3803|23-12-2015|      pot plants|      5|
# |         2762|20-03-2015|      whole milk|      1|
# |         4119| 12/2/2015|  tropical fruit|      0|
# +-------------+----------+----------------+-------+

# %% [markdown]
# ### CREATE .db file of the created database using sqlite3

# %%
import sqlite3

# Create SQLite database
conn = sqlite3.connect('/content/products.db')

tables = ['customer', 'product', 'product_details', 'ratings', 'reviews', 'transactions']

for table in tables:
    df = spark.sql(f"SELECT * FROM Products.{table}")
    df_pandas = df.toPandas()
    df_pandas.to_sql(table, conn, if_exists='replace', index=False)
    print(f"Exported {table} to products.db")

conn.close()

# Download the database file (in Colab)
from google.colab import files
files.download('/content/products.db')
# Out:
# Exported customer to products.db
# Exported product to products.db
# Exported product_details to products.db
# Exported ratings to products.db
# Exported reviews to products.db
# Exported transactions to products.db
